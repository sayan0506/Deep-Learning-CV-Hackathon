# %% [markdown]
# <a href="https://colab.research.google.com/github/sayan0506/Deep-Learning-CV-Hackathon/blob/main/Face_Verification_Based_Attendance_System_using_Arcface_Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Verification using Arcface, Siamese network training using triplet loss**

# %% [markdown]
# ## **Import Dependencies**

# %%
import zipfile
import os

# %% [markdown]
# ## **Drive mount**

# %%
# drive mount
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Data Load**

# %% [markdown]
# #### Unzipping
#
# Defining the unzipping function

# %%
# unzip function
def unzip_file(src, dst):
  # create a destination folder if not exists
  if not os.path.isdir(dst):
    os.mkdir(dst)
  print(f'The unzipped files will be stored to "{dst}" destination folder')

  with zipfile.ZipFile(src, 'r') as zip_ref:
    zip_ref.extractall(dst)

# %% [markdown]
# **Drive link: [face_train_set.zip](https://drive.google.com/file/d/1r5QjkBxspHILq1Bc_xpr7apbGWx1cmzy/view?usp=sharing)**

# %%
# zip path(in drive) containing individual class folders
zip_filepath = '/content/drive/MyDrive/face_trainset/face_train_set.zip'

# destination face trainset folder
dst_path = 'face_trainset'

# %% [markdown]
# **Unzipping**

# %%
unzip_file(zip_filepath, dst_path)
# Out:
# The unzipped files will be stored to "face_trainset" destination folder

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# Note: It's checked that, there is no .dstore or other files in the dataset folder, so each of the folder corresponds to uniquee identity, thus total list of directories equals to total identities.

# %%
face_dataset_path = "/content/face_trainset/face_train_set"

# classifiers count
classifiers = os.listdir(face_dataset_path)

# %% [markdown]
# #### Fetching image info corresponding to individual classes
#
# Fetching image info to image dictionary. Key corresponds to individual class, and value for that class will be list of all the image ids

# %%
# image dictionary
img_dict = {}

# image counts
img_count = 0

for identity in os.listdir(face_dataset_path):
  path = os.path.join(face_dataset_path, identity)
  img_dict[identity] = os.listdir(path)
  img_count+= len(os.listdir(path))

print(f'Image dictionary\n{img_dict}')
# Out:
# Image dictionary
# {'0013_0002413': ['0000002.jpg', '0013_0002413_script.jpg'], '0007_0001019': ['0007_0001019_script.jpg', '0000000.jpg', '0000008.jpg'], '0007_0001124': ['0000006.jpg', '0000002.jpg', '0007_0001124_script.jpg', '0000000.jpg', '0000005.jpg', '0000008.jpg', '0000004.jpg'], '0007_0001066': ['0000000.jpg', '0007_0001066_script.jpg'], '0007_0000956': ['0000001.jpg', '0007_0000956_script.jpg'], '0007_0001021': ['0007_0001021_script.jpg', '0000002.jpg', '0000009.jpg', '0000007.jpg', '0000001.jpg'], '0007_0001315': ['0000001.jpg', '0000005.jpg', '0007_0001315_script.jpg'], '0013_0002065': ['0013_0002065_script.jpg', '0000000.jpg', '0000004.jpg'], '0007_0000978': ['0007_0000978_script.jpg', '0000000.jpg', '0000005.jpg'], '0010_0001632': ['0000002.jpg', '0010_0001632_script.jpg', '0000000.jpg', '0000007.jpg', '0000008.jpg'], '0007_0001374': ['0000006.jpg', '0007_0001374_script.jpg', '0000000.jpg', '0000001.jpg'], '0014_0002571': ['0014_0002571_script.jpg', '0000004.jpg'], '0007_0000710': ['0000010.jpg', '0000007.jpg', '0007_0000710_script.jpg', '0000005.jpg'], '0013_0002057': ['0000000.jpg', '0000001.jpg', '0013_0002057_script.jpg'], '0013_0002114': ['0013_0002114_script.jpg', '0000010.jpg', '0000007.jpg', '0000001.jpg', '0013_0002114_script_2.jpg'], '0013_0001892': ['0013_0001892_script.jpg', '0000007.jpg', '0000005.jpg'], '0007_0001070': ['0000006.jpg', '0000000.jpg', '0007_0001070_script_2.jpg', '0007_0001070_script.jpg'], '0013_0002207': ['0013_0002207_script.jpg', '0000005.jpg'], '0006_0000630': ['0006_0000630_script.jpg', '0000001.jpg', '0000004.jpg'], '0013_0002002': ['0000006.jpg', '0013_0002002_script.jpg', '0000007.jpg', '0013_0002002_script_2.jpg', '0000005.jpg'], '0007_0000741': ['0000006.jpg', '0000000.jpg', '0000007.jpg', '0000008.jpg', '0007_0000741_script.jpg', '0000004.jpg'], '0013_0002449': ['0000002.jpg', '0000000.jpg', '0000001.jpg', '0013_0002449_script.jpg', '0000008.jpg'], '0010_0001608': ['0010_0001608_script.jpg', '0000003.jpg', '0000011.jpg'], '0006_0000582': ['0006_0000582_script.jpg', '0000001.jpg', '0000005.jpg', '0000004.jpg'], '0007_0000996': ['0007_0000996_script.jpg', '0000000.jpg'], '0007_0001018': ['0000006.jpg', '0000002.jpg', '0007_0001018_script.jpg', '0000004.jpg'], '0013_0002248': ['0000006.jpg', '0000000.jpg', '0000007.jpg', '0000008.jpg', '0013_0002248_script.jpg', '0000004.jpg'], '0007_0001433': ['0007_0001433_script.jpg', '0000004.jpg'], '0007_0000786': ['0000006.jpg', '0000000.jpg', '0007_0000786_script.jpg', '0000004.jpg'], '0013_0002284': ['0013_0002284_script.jpg', '0000000.jpg', '0000010.jpg', '0000008.jpg', '0013_0002284_script_2.jpg'], '0007_0000946': ['0000006.jpg', '0000009.jpg', '0007_0000946_script.jpg', '0000007.jpg', '0000001.jpg', '0000005.jpg', '0000004.jpg'], '0007_0001069': ['0000003.jpg', '0000007.jpg', '0000008.jpg', '0007_0001069_script_2.jpg', '0007_0001069_script.jpg'], '0013_0002446': ['0013_0002446_script.jpg', '0000001.jpg', '0000008.jpg'], '0007_0000780': ['0000006.jpg', '0007_0000780_script.jpg'], '0007_0001134': ['0007_0001134_script.jpg', '0000006.jpg', '0000000.jpg'], '0007_0000838': ['0000002.jpg', '0000009.jpg', '0000000.jpg', '0000010.jpg', '0000005.jpg', '0007_0000838_script.jpg', '0000011.jpg'], '0005_0000464': ['0000000.jpg', '0005_0000464_script.jpg', '0000011.jpg'], '0013_0002164': ['0013_0002164_script.jpg', '0000005.jpg'], '0013_0002441': ['0013_0002441_script.jpg', '0000000.jpg'], '0013_0001993': ['0000003.jpg', '0000009.jpg', '0000007.jpg', '0013_0001993_script_2.jpg', '0000001.jpg', '0013_0001993_script.jpg', '0000005.jpg', '0000004.jpg'], '0007_0001052': ['0000006.jpg', '0000001.jpg', '0000008.jpg', '0007_0001052_script.jpg'], '0013_0002333': ['0000000.jpg', '0013_0002333_script.jpg', '0000005.jpg'], '0007_0000839': ['0000006.jpg', '0007_0000839_script.jpg', '0000000.jpg', '0000010.jpg', '0000004.jpg'], '0007_0001310': ['0007_0001310_script.jpg', '0000002.jpg', '0000000.jpg', '0000007.jpg', '0000001.jpg', '0000005.jpg'], '0007_0001333': ['0000003.jpg' ...

# %%
print(f'Total {img_count} images available corresponds to {len(img_dict.keys())} identities')
# Out:
# Total 4419 images available corresponds to 1012 identities
