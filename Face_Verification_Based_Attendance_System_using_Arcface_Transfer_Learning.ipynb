# %% [markdown]
# <a href="https://colab.research.google.com/github/sayan0506/Deep-Learning-CV-Hackathon/blob/main/Face_Verification_Based_Attendance_System_using_Arcface_Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Verification using Arcface, Siamese network training using triplet loss**

# %% [markdown]
# ## **Import Dependencies**

# %%
import zipfile
import os

# %% [markdown]
# ## **Drive mount**

# %%
# drive mount
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Data Load**

# %% [markdown]
# #### Unzipping
#
# Defining the unzipping function

# %%
# unzip function
def unzip_file(src, dst):
  # create a destination folder if not exists
  if not os.path.isdir(dst):
    os.mkdir(dst)
  print(f'The unzipped files will be stored to "{dst}" destination folder')

  with zipfile.ZipFile(src, 'r') as zip_ref:
    zip_ref.extractall(dst)

# %% [markdown]
# **Drive link: [face_train_set.zip](https://drive.google.com/file/d/1r5QjkBxspHILq1Bc_xpr7apbGWx1cmzy/view?usp=sharing)**

# %%
# zip path(in drive) containing individual class folders
zip_filepath = '/content/drive/MyDrive/face_trainset/face_train_set.zip'

# destination face trainset folder
dst_path = 'face_trainset'

# %% [markdown]
# **Unzipping**

# %%
unzip_file(zip_filepath, dst_path)
# Out:
# The unzipped files will be stored to "face_trainset" destination folder

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# Note: It's checked that, there is no .dstore or other files in the dataset folder, so each of the folder corresponds to uniquee identity, thus total list of directories equals to total identities.

# %%
face_dataset_path = "/content/face_trainset/face_train_set"

# classifiers count
classifiers = os.listdir(face_dataset_path)

print(f'Total {len(classifiers)} unique identies are there, as following\n{classifiers}')

'''
for identity in classifiers:
  print(identity)
'''
# Out:
# Total 1012 unique identies are there, as following
# ['0013_0002413', '0007_0001019', '0007_0001124', '0007_0001066', '0007_0000956', '0007_0001021', '0007_0001315', '0013_0002065', '0007_0000978', '0010_0001632', '0007_0001374', '0014_0002571', '0007_0000710', '0013_0002057', '0013_0002114', '0013_0001892', '0007_0001070', '0013_0002207', '0006_0000630', '0013_0002002', '0007_0000741', '0013_0002449', '0010_0001608', '0006_0000582', '0007_0000996', '0007_0001018', '0013_0002248', '0007_0001433', '0007_0000786', '0013_0002284', '0007_0000946', '0007_0001069', '0013_0002446', '0007_0000780', '0007_0001134', '0007_0000838', '0005_0000464', '0013_0002164', '0013_0002441', '0013_0001993', '0007_0001052', '0013_0002333', '0007_0000839', '0007_0001310', '0007_0001333', '0006_0000575', '0007_0001323', '0007_0001045', '0013_0002461', '0005_0000463', '0007_0001032', '0007_0000840', '0013_0002238', '0003_0000329', '0007_0001324', '0007_0001296', '0007_0001250', '0013_0002271', '0007_0001353', '0009_0001549', '0013_0001831', '0003_0000371', '0006_0000584', '0007_0001001', '0013_0002214', '0007_0000760', '0007_0001187', '0013_0001750', '0007_0001093', '0013_0001979', '0013_0002433', '0007_0000692', '0007_0001204', '0013_0002150', '0007_0001108', '0013_0002227', '0007